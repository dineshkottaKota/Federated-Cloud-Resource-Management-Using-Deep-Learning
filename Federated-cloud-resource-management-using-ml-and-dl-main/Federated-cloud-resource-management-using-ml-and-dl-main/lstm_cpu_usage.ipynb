# %%
#-----------------------------------------------------------
# IMPORT ALL NECESSARY MODULES
#-----------------------------------------------------------

import numpy as np
# %matplotlib inline
import pandas as pd
import tensorflow as tf
from IPython.display import display, Image
import cv2
from PIL import Image
from tqdm import tqdm
from keras.applications.vgg19 import VGG19
from keras.utils import plot_model
import gc
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import accuracy_score

# %%
#-----------------------------------------------------------
# LOAD THE DATASET AND PLOT THE OBSERVATIONS
#-----------------------------------------------------------

df = pd.read_csv('azure.csv')
df['timestamp'] =  pd.to_datetime(df['timestamp'])
df = df.set_index('timestamp')
df.head()
df.plot(figsize=(16, 8))
plt.show()

# %%
#-----------------------------------------------------------
# CREATE TRAIN-TEST SPLIT (80:20)
#-----------------------------------------------------------
TRAIN_LENGTH = round(len(df)*0.8)
TEST_LENGTH = len(df) - TRAIN_LENGTH
train = df.iloc[0:TRAIN_LENGTH]
test = df[TRAIN_LENGTH : ]

# %%
#-----------------------------------------------------------
# SCALING VALUES
#-----------------------------------------------------------
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = pd.DataFrame(scaler.fit_transform(train), columns=df.columns)
test_scaled = pd.DataFrame(scaler.transform(test), columns=df.columns)

# %%
#-----------------------------------------------------------
# GENERATOR TO DATA TO FEED INTO MODEL
#-----------------------------------------------------------
def train_generator(dataset, n_lags=1):
    dataX, dataY = [], []
    for i in range(len(dataset)- n_lags -1):
        a = dataset.iloc[i:(i+n_lags)].to_numpy()
        dataX.append(a)
        dataY.append(dataset.iloc[i + n_lags].to_numpy())
    return (np.array(dataX), np.array(dataY))

# %%
#-----------------------------------------------------------
# DEFINING INPUTS AND EXPECTED OBSERVATIONS
#-----------------------------------------------------------
TIME_STEPS = 500
X_train, y_train = train_generator(train_scaled, n_lags = TIME_STEPS)
X_test_scaled, y_test_scaled = train_generator(test_scaled, n_lags = TIME_STEPS)
X_test, y_test = train_generator(test, n_lags = TIME_STEPS)

# %%
#-----------------------------------------------------------
# USING A LSTM MODEL FOR PREDICTION ON TIME SERIES
#-----------------------------------------------------------
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(512,input_shape=(X_train.shape[1], X_train.shape[2]),return_sequences=True))
model.add(tf.keras.layers.LSTM(512,return_sequences=False))
model.add(tf.keras.layers.Dense(3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 500, 512)          1056768
#
#  lstm_1 (LSTM)               (None, 512)               2099200
#
#  dense (Dense)               (None, 3)                 1539
#
# =================================================================
# Total params: 3157507 (12.04 MB)
# Trainable params: 3157507 (12.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_absolute_error', optimizer= tf.keras.optimizers.Adam(),metrics=['accuracy'])

# %%
#-----------------------------------------------------------
# DEFINING CALLBACKS
#-----------------------------------------------------------
es = tf.keras.callbacks.EarlyStopping( monitor='val_loss', patience=8, verbose=1, restore_best_weights=True)
lr_red = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1, min_lr=0.0000001,)

# %%
callbacks = [es , lr_red]
history = model.fit(X_train, y_train,
                    epochs=50,
                    validation_split=0.25,
                    batch_size=256,
                    verbose=1,
                    shuffle=False,
                    callbacks = callbacks)

#-----------------------------------------------------------
# I TRAINED MY MODEL ON BATCHSIZES - 64,128,256
#-----------------------------------------------------------
# Out:
# Epoch 1/50
# 19/19 [==============================] - 22s 983ms/step - loss: 0.0273 - accuracy: 0.8378 - val_loss: 0.0228 - val_accuracy: 0.9164 - lr: 0.0010
# Epoch 2/50
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0201 - accuracy: 0.7903 - val_loss: 0.0187 - val_accuracy: 0.9201 - lr: 0.0010
# Epoch
- val_accuracy: 0.8939 - lr: 2.0000e-04
# Epoch 20/50
# 19/19 [==============================] - 18s 959ms/step - loss: 0.0154 - accuracy: 0.8421 - val_loss: 0.0160 - val_accuracy: 0.9033 - lr: 2.0000e-04
# Epoch 21/50
# 19/19 [==============================] - 19s 995ms/step - loss: 0.0154 - accuracy: 0.8419 - val_loss: 0.0159 - val_accuracy: 0.9133 - lr: 2.0000e-04
# Epoch 22/50
# 19/19 [==============================] - 18s 954ms/step - loss: 0.0154 - accuracy: 0.8419 - val_loss: 0.0158 - val_accuracy: 0.9170 - lr: 2.0000e-04
# Epoch 23/50
# 19/19 [==============================] - 19s 991ms/step - loss: 0.0153 - accuracy: 0.8438 - val_loss: 0.0157 - val_accuracy: 0.9226 - lr: 2.0000e-04
# Epoch 24/50
# 19/19 [==============================] - 19s 991ms/step - loss: 0.0153 - accuracy: 0.8478 - val_loss: 0.0156 - val_accuracy: 0.9258 - lr: 2.0000e-04
# Epoch 25/50
# 19/19 [==============================] - 18s 953ms/step - loss: 0.0154 - accuracy: 0.8505 - val_loss: 0.0158 - val_accuracy: 0.9226 - lr: 2.0000e-04
# Epoch 26/50
# 19/19 [==============================] - 19s 993ms/step - loss: 0.0153 - accuracy: 0.8469 - val_loss: 0.0159 - val_accuracy: 0.9214 - lr: 2.0000e-04
# Epoch 27/50
# 19/19 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.8384
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 19/19 [==============================] - 18s 956ms/step - loss: 0.0153 - accuracy: 0.8384 - val_loss: 0.0160 - val_accuracy: 0.9214 - lr: 2.0000e-04
# Epoch 28/50
# 19/19 [==============================] - 18s 953ms/step - loss: 0.0157 - accuracy: 0.8301 - val_loss: 0.0161 - val_accuracy: 0.8952 - lr: 4.0000e-05
# Epoch 29/50
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0149 - accuracy: 0.8411 - val_loss: 0.0158 - val_accuracy: 0.8989 - lr: 4.0000e-05
# Epoch 30/50
# 19/19 [==============================] - 18s 954ms/step - loss: 0.0147 - accuracy: 0.8469 - val_loss: 0.0157 - val_accuracy: 0.9002 - lr: 4.0000e-05
# Epoch 31/50
# 19/19 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.8478
# Epoch 31: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 19/19 [==============================] - 18s 954ms/step - loss: 0.0146 - accuracy: 0.8478 - val_loss: 0.0156 - val_accuracy: 0.9014 - lr: 4.0000e-05
# Epoch 32/50
# 19/19 [==============================] - 18s 953ms/step - loss: 0.0144 - accuracy: 0.8513 - val_loss: 0.0156 - val_accuracy: 0.9014 - lr: 8.0000e-06
# Epoch 33/50
# 19/19 [==============================] - 19s 991ms/step - loss: 0.0144 - accuracy: 0.8509 - val_loss: 0.0156 - val_accuracy: 0.9027 - lr: 8.0000e-06
# Epoch 34/50
# 19/19 [==============================] - 18s 954ms/step - loss: 0.0144 - accuracy: 0.8527 - val_loss: 0.0155 - val_accuracy: 0.9046 - lr: 8.0000e-06
# Epoch 35/50
# 19/19 [==============================] - 19s 993ms/step - loss: 0.0144 - accuracy: 0.8534 - val_loss: 0.0155 - val_accuracy: 0.9064 - lr: 8.0000e-06
# Epoch 36/50
# 19/19 [==============================] - 19s 994ms/step - loss: 0.0144 - accuracy: 0.8536 - val_loss: 0.0155 - val_accuracy: 0.9083 - lr: 8.0000e-06
# Epoch 37/50
# 19/19 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.8542
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0143 - accuracy: 0.8542 - val_loss: 0.0155 - val_accuracy: 0.9108 - lr: 8.0000e-06
# Epoch 38/50
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0143 - accuracy: 0.8550 - val_loss: 0.0155 - val_accuracy: 0.9108 - lr: 1.6000e-06
# Epoch 39/50
# 19/19 [==============================] - 19s 992ms/step - loss: 0.0143 - accuracy: 0.8552 - val_loss: 0.0155 - val_accuracy: 0.9108 - lr: 1.6000e-06
# Epoch 40/50
# 19/19 [==============================] - 18s 953ms/step - loss: 0.0143 - accuracy: 0.8559 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.6000e-06
# Epoch 41/50
# 19/19 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.8561
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 19/19 [==============================] - 18s 953ms/step - loss: 0.0143 - accuracy: 0.8561 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.6000e-06
# Epoch 42/50
# 19/19 [==============================] - 19s 992ms/step - loss: 0.0143 - accuracy: 0.8563 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 3.2000e-07
# Epoch 43/50
# 19/19 [==============================] - 19s 993ms/step - loss: 0.0143 - accuracy: 0.8565 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 3.2000e-07
# Epoch 44/50
# 19/19 [==============================] - 19s 992ms/step - loss: 0.0143 - accuracy: 0.8565 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 3.2000e-07
# Epoch 45/50
# 19/19 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.8565
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1e-07.
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0143 - accuracy: 0.8565 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 3.2000e-07
# Epoch 46/50
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0143 - accuracy: 0.8567 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.0000e-07
# Epoch 47/50
# 19/19 [==============================] - 18s 956ms/step - loss: 0.0143 - accuracy: 0.8567 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.0000e-07
# Epoch 48/50
# 19/19 [==============================] - 18s 953ms/step - loss: 0.0143 - accuracy: 0.8567 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.0000e-07
# Epoch 49/50
# 19/19 [==============================] - 19s 992ms/step - loss: 0.0143 - accuracy: 0.8567 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.0000e-07
# Epoch 50/50
# 19/19 [==============================] - 18s 950ms/step - loss: 0.0143 - accuracy: 0.8567 - val_loss: 0.0155 - val_accuracy: 0.9127 - lr: 1.0000e-07

# %%
#-----------------------------------------------------------
# MAKING PREDICTIONS ON TEST DATA AND PLOTTING PREDICTED AND
# OBSERVED VALUES
#-----------------------------------------------------------
preds = model.predict(X_test_scaled)
preds = scaler.inverse_transform(preds)
plt.rcParams["figure.figsize"] = (32,12)
TestY= pd.DataFrame(y_test,columns=['min_cpu','max_cpu','avg_cpu'])
PredY=pd.DataFrame(preds,columns=['min_cpu','max_cpu','avg_cpu'])


plot_max = plt.figure(1)
plt.plot(TestY['max_cpu'])
plt.plot(PredY['max_cpu'])
plt.show()

plot_min = plt.figure(2)
plt.plot(TestY['min_cpu'])
plt.plot(PredY['min_cpu'])
plt.show()

plot_avg = plt.figure(3)
plt.plot(TestY['avg_cpu'])
plt.plot(PredY['avg_cpu'])
plt.show()
# Out:
# 39/39 [==============================] - 3s 58ms/step

# %%
#-----------------------------------------------------------
# LETS CHECK HOW GOOD THE MODEL PERFORMED
#-----------------------------------------------------------
testScore_1 = math.sqrt(mean_squared_error(y_test[:], preds[:]))
print('Test Score: %.2f RMSE' % (testScore_1))

testScore_2 = math.sqrt(mean_absolute_error(y_test[:], preds[:]))
print('Test Score: %f MAE' % (testScore_2))

testScore_3 = np.mean(np.abs(preds - y_test)/np.abs(y_test)*100)
print('Test Score: %f MAPE' % (testScore_3))
# Out:
# Test Score: 26015.87 RMSE
# Test Score: 130.575008 MAE
# Test Score: 1.156160 MAPE

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py

# Import helper functions we're going to use
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, walk_through_dir
# Out:
# --2023-12-03 06:20:06--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0.001s
#
# 2023-12-03 06:20:06 (13.5 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
plot_loss_curves(history)
